# %% [markdown]
# ## 1. Generate pan gene pairs for kaks calculation based on OG matrix
#
# ## 2. Plotting kaks results for core and dispensable genes
#
# ## 3. Plotting kaks results for different subfamilies

# %%
##/Volumes/Elements5T/Programs/Students/Tong_bhlh_transcriptome_heatmap
import pandas as pd
import numpy as np

# %%
pan_gene = "pangenome_matrix_genes_t0.tr.tab"
target_gene = "tongcen_bhlh_v2_id_list_match_panMorex.txt"

# %%
df_pan = pd.read_csv(pan_gene,header=0, delim_whitespace=True)
df_pan.head()
# Out:
#   source:/data/pangenome_cluster_analysis/clusters_cds_t3  \
# 0                245_Horvu_AKASHIN_Un01G001600.1.fna
# 1                247_Horvu_AKASHIN_7H01G134100.1.fna
# 2                311_Horvu_AKASHIN_1H01G008000.1.fna
# 3                345_Horvu_AKASHIN_2H01G445100.1.fna
# 4                391_Horvu_AKASHIN_5H01G712000.1.fna
#
#                                 Akashinriki.fna.nucl B1K-04-12.fna.nucl  \
# 0                       Horvu_AKASHIN_Un01G001600.1,                  -
# 1                       Horvu_AKASHIN_7H01G134100.1,                  -
# 2                       Horvu_AKASHIN_1H01G008000.1,                  -
# 3  Horvu_AKASHIN_2H01G445100.1,Horvu_AKASHIN_5H01...                  -
# 4                       Horvu_AKASHIN_5H01G712000.1,                  -
#
#                Barke.fna.nucl      Golden_Promise.fna.nucl  \
# 0  Horvu_BARKE_4H01G004600.1,  Horvu_GOLDEN_Un01G008000.1,
# 1                           -                            -
# ...

# %%
df_target = pd.read_csv(target_gene,header=None,sep="\t")
df_target.columns = ["V1","V2"]
df_target.head()
# Out:
#                           V1                           V2
# 0  Horvu_MOREX_4H01G139200.1  HORVU.MOREX.r2.4HG0292190.1
# 1  Horvu_MOREX_1H01G318500.1  HORVU.MOREX.r2.1HG0041620.1
# 2  Horvu_MOREX_1H01G132600.1  HORVU.MOREX.r2.1HG0016740.1
# 3  Horvu_MOREX_6H01G260800.1  HORVU.MOREX.r2.6HG0481020.1
# 4  Horvu_MOREX_3H01G206900.1  HORVU.MOREX.r2.3HG0207450.1

# %%
df_pan = df_pan.replace('-', np.nan)
df_pan = df_pan[df_pan["Morex.fna.nucl"].notna()]

# %%
df_pan.head()
# Out:
#      source:/data/pangenome_cluster_analysis/clusters_cds_t3  \
# 4704               676266_Horvu_MOREX_1H01G240300.1.fna
# 4705               676267_Horvu_MOREX_5H01G284200.1.fna
# 4706               676268_Horvu_MOREX_2H01G748500.1.fna
# 4707               676269_Horvu_MOREX_6H01G294100.1.fna
# 4708               676270_Horvu_MOREX_1H01G348900.1.fna
#
#               Akashinriki.fna.nucl         B1K-04-12.fna.nucl  \
# 4704  Horvu_AKASHIN_1H01G226200.1,  Horvu_FT11_1H01G235900.1,
# 4705  Horvu_AKASHIN_5H01G267000.1,  Horvu_FT11_5H01G274800.1,
# 4706  Horvu_AKASHIN_2H01G719600.1,  Horvu_FT11_2H01G723900.1,
# 4707  Horvu_AKASHIN_6H01G269100.1,  Horvu_FT11_6H01G286000.1,
# 4708  Horvu_AKASHIN_1H01G332200.1,  Horvu_FT11_1H01G342700.1,
#
#                   Barke.fna.nucl      Golden_Promise.fna.nucl  \
# 4704  Horvu_BARKE_1H01G243000.1,  Horvu_GOLDEN_1H01G192000.1,
# 4705  Horvu_BARKE_5H01G280000.1,  Horvu_GOLDEN_5H01G243900.1,
# ...

# %%
df_pan = df_pan.assign(Morex=df_pan["Morex.fna.nucl"].str.split(","))

# %%
df_pan = df_pan.explode("Morex")

# %%
df_pan.shape
# Out:
# (75083, 22)

# %%
df_pan = df_pan[df_pan["Morex"].notna()]

# %%
df_pan = df_pan.reset_index()

# %%
df_pan.head()
# Out:
#    index source:/data/pangenome_cluster_analysis/clusters_cds_t3  \
# 0   4704               676266_Horvu_MOREX_1H01G240300.1.fna
# 1   4704               676266_Horvu_MOREX_1H01G240300.1.fna
# 2   4705               676267_Horvu_MOREX_5H01G284200.1.fna
# 3   4705               676267_Horvu_MOREX_5H01G284200.1.fna
# 4   4706               676268_Horvu_MOREX_2H01G748500.1.fna
#
#            Akashinriki.fna.nucl         B1K-04-12.fna.nucl  \
# 0  Horvu_AKASHIN_1H01G226200.1,  Horvu_FT11_1H01G235900.1,
# 1  Horvu_AKASHIN_1H01G226200.1,  Horvu_FT11_1H01G235900.1,
# 2  Horvu_AKASHIN_5H01G267000.1,  Horvu_FT11_5H01G274800.1,
# 3  Horvu_AKASHIN_5H01G267000.1,  Horvu_FT11_5H01G274800.1,
# 4  Horvu_AKASHIN_2H01G719600.1,  Horvu_FT11_2H01G723900.1,
#
#                Barke.fna.nucl      Golden_Promise.fna.nucl  \
# 0  Horvu_BARKE_1H01G243000.1,  Horvu_GOLDEN_1H01G192000.1,
# 1  Horvu_BARKE_1H01G243000.1,  Horvu_GOLDEN_1H01G192000.1,
# 2  Horvu_BARKE_5H01G280000.1,  Horvu_GOLDEN_5H01G243900.1,
# ...

# %%
df_pan.loc[1,"Morex"]
# Out:
# ''

# %%
df_pan = df_pan.replace('', np.nan)

# %%
df_pan = df_pan[df_pan["Morex"].notna()]

# %%
df_pan.head()
# Out:
#    index source:/data/pangenome_cluster_analysis/clusters_cds_t3  \
# 0   4704               676266_Horvu_MOREX_1H01G240300.1.fna
# 2   4705               676267_Horvu_MOREX_5H01G284200.1.fna
# 4   4706               676268_Horvu_MOREX_2H01G748500.1.fna
# 6   4707               676269_Horvu_MOREX_6H01G294100.1.fna
# 8   4708               676270_Horvu_MOREX_1H01G348900.1.fna
#
#            Akashinriki.fna.nucl         B1K-04-12.fna.nucl  \
# 0  Horvu_AKASHIN_1H01G226200.1,  Horvu_FT11_1H01G235900.1,
# 2  Horvu_AKASHIN_5H01G267000.1,  Horvu_FT11_5H01G274800.1,
# 4  Horvu_AKASHIN_2H01G719600.1,  Horvu_FT11_2H01G723900.1,
# 6  Horvu_AKASHIN_6H01G269100.1,  Horvu_FT11_6H01G286000.1,
# 8  Horvu_AKASHIN_1H01G332200.1,  Horvu_FT11_1H01G342700.1,
#
#                Barke.fna.nucl      Golden_Promise.fna.nucl  \
# 0  Horvu_BARKE_1H01G243000.1,  Horvu_GOLDEN_1H01G192000.1,
# 2  Horvu_BARKE_5H01G280000.1,  Horvu_GOLDEN_5H01G243900.1,
# 4  Horvu_BARKE_2H01G731300.1,  Horvu_GOLDEN_2H01G666000.1,
# ...

# %%
df_target.head()
# Out:
#                           V1                           V2
# 0  Horvu_MOREX_4H01G139200.1  HORVU.MOREX.r2.4HG0292190.1
# 1  Horvu_MOREX_1H01G318500.1  HORVU.MOREX.r2.1HG0041620.1
# 2  Horvu_MOREX_1H01G132600.1  HORVU.MOREX.r2.1HG0016740.1
# 3  Horvu_MOREX_6H01G260800.1  HORVU.MOREX.r2.6HG0481020.1
# 4  Horvu_MOREX_3H01G206900.1  HORVU.MOREX.r2.3HG0207450.1

# %%
## filter pan gene matrix using target bHLH genes
df_merged = df_target.merge(df_pan,left_on="V1",right_on="Morex",how="left")
df_merged.head()
# Out:
#                           V1                           V2    index  \
# 0  Horvu_MOREX_4H01G139200.1  HORVU.MOREX.r2.4HG0292190.1   6832.0
# 1  Horvu_MOREX_1H01G318500.1  HORVU.MOREX.r2.1HG0041620.1   9076.0
# 2  Horvu_MOREX_1H01G132600.1  HORVU.MOREX.r2.1HG0016740.1   9724.0
# 3  Horvu_MOREX_6H01G260800.1  HORVU.MOREX.r2.6HG0481020.1   9822.0
# 4  Horvu_MOREX_3H01G206900.1  HORVU.MOREX.r2.3HG0207450.1  10197.0
#
#   source:/data/pangenome_cluster_analysis/clusters_cds_t3  \
# 0               678596_Horvu_MOREX_4H01G139200.1.fna
# 1               680975_Horvu_MOREX_1H01G318500.1.fna
# 2               681681_Horvu_MOREX_1H01G132600.1.fna
# 3               681790_Horvu_MOREX_6H01G260800.1.fna
# 4               682211_Horvu_MOREX_3H01G206900.1.fna
#
#            Akashinriki.fna.nucl         B1K-04-12.fna.nucl  \
# 0  Horvu_AKASHIN_4H01G131500.1,  Horvu_FT11_4H01G138300.1,
# 1  Horvu_AKASHIN_1H01G302800.1,  Horvu_FT11_1H01G313700.1,
# ...

# %%
df_merged.shape
# Out:
# (160, 25)

# %%
df_merged.columns.to_list()
# Out:
# ['V1',
#  'V2',
#  'index',
#  'source:/data/pangenome_cluster_analysis/clusters_cds_t3',
#  'Akashinriki.fna.nucl',
#  'B1K-04-12.fna.nucl',
#  'Barke.fna.nucl',
#  'Golden_Promise.fna.nucl',
#  'HOR_10350.fna.nucl',
#  'HOR_13821.fna.nucl',
#  'HOR_13942.fna.nucl',
#  'HOR_21599.fna.nucl',
#  'HOR_3081.fna.nucl',
#  'HOR_3365.fna.nucl',
#  'HOR_7552.fna.nucl',
#  'HOR_8148.fna.nucl',
#  'HOR_9043.fna.nucl',
#  'Hockett.fna.nucl',
#  'Igri.fna.nucl',
#  'Morex.fna.nucl',
#  'OUN333.fna.nucl',
#  'RGT_Planet.fna.nucl',
#  'ZDM01467.fna.nucl',
#  'ZDM02064.fna.nucl',
#  'Morex']

# %%
## subset df_merged to remove unwanted columns
df_merged = df_merged[['V1',
 'V2',
 'Akashinriki.fna.nucl',
 'B1K-04-12.fna.nucl',
 'Barke.fna.nucl',
 'Golden_Promise.fna.nucl',
 'HOR_10350.fna.nucl',
 'HOR_13821.fna.nucl',
 'HOR_13942.fna.nucl',
 'HOR_21599.fna.nucl',
 'HOR_3081.fna.nucl',
 'HOR_3365.fna.nucl',
 'HOR_7552.fna.nucl',
 'HOR_8148.fna.nucl',
 'HOR_9043.fna.nucl',
 'Hockett.fna.nucl',
 'Igri.fna.nucl',
 'OUN333.fna.nucl',
 'RGT_Planet.fna.nucl',
 'ZDM01467.fna.nucl',
 'ZDM02064.fna.nucl',
 'Morex']]

# %%
df_merged.head()
# Out:
#                           V1                           V2  \
# 0  Horvu_MOREX_4H01G139200.1  HORVU.MOREX.r2.4HG0292190.1
# 1  Horvu_MOREX_1H01G318500.1  HORVU.MOREX.r2.1HG0041620.1
# 2  Horvu_MOREX_1H01G132600.1  HORVU.MOREX.r2.1HG0016740.1
# 3  Horvu_MOREX_6H01G260800.1  HORVU.MOREX.r2.6HG0481020.1
# 4  Horvu_MOREX_3H01G206900.1  HORVU.MOREX.r2.3HG0207450.1
#
#            Akashinriki.fna.nucl         B1K-04-12.fna.nucl  \
# 0  Horvu_AKASHIN_4H01G131500.1,  Horvu_FT11_4H01G138300.1,
# 1  Horvu_AKASHIN_1H01G302800.1,  Horvu_FT11_1H01G313700.1,
# 2  Horvu_AKASHIN_1H01G124100.1,  Horvu_FT11_1H01G131500.1,
# 3  Horvu_AKASHIN_6H01G238000.1,  Horvu_FT11_6H01G255700.1,
# 4  Horvu_AKASHIN_3H01G201200.1,  Horvu_FT11_3H01G210800.1,
#
#                Barke.fna.nucl      Golden_Promise.fna.nucl  \
# 0  Horvu_BARKE_4H01G134900.1,  Horvu_GOLDEN_4H01G120100.1,
# 1  Horvu_BARKE_1H01G319700.1,  Horvu_GOLDEN_1H01G265800.1,
# 2  Horvu_BARKE_1H01G134200.1,  Horvu_GOLDEN_1H01G100100.1,
# ...

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 160 entries, 0 to 159
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   V1                       160 non-null    object
#  1   V2                       155 non-null    object
#  2   Akashinriki.fna.nucl     152 non-null    object
#  3   B1K-04-12.fna.nucl       152 non-null    object
#  4   Barke.fna.nucl           151 non-null    object
#  5   Golden_Promise.fna.nucl  150 non-null    object
#  6   HOR_10350.fna.nucl       152 non-null    object
#  7   HOR_13821.fna.nucl       150 non-null    object
#  8   HOR_13942.fna.nucl       153 non-null    object
#  9   HOR_21599.fna.nucl       154 non-null    object
#  10  HOR_3081.fna.nucl        153 non-null    object
#  11  HOR_3365.fna.nucl        151 non-null    object
#  12  HOR_7552.fna.nucl        152 non-null    object
#  13  HOR_8148.fna.nucl        150 non-null    object
# ...

# %%
## strip last "," in each cell
df_merged[df_merged.columns] = df_merged.apply(lambda x: x.str.strip(","))

# %%
df_merged.head()
# Out:
#                           V1                           V2  \
# 0  Horvu_MOREX_4H01G139200.1  HORVU.MOREX.r2.4HG0292190.1
# 1  Horvu_MOREX_1H01G318500.1  HORVU.MOREX.r2.1HG0041620.1
# 2  Horvu_MOREX_1H01G132600.1  HORVU.MOREX.r2.1HG0016740.1
# 3  Horvu_MOREX_6H01G260800.1  HORVU.MOREX.r2.6HG0481020.1
# 4  Horvu_MOREX_3H01G206900.1  HORVU.MOREX.r2.3HG0207450.1
#
#           Akashinriki.fna.nucl        B1K-04-12.fna.nucl  \
# 0  Horvu_AKASHIN_4H01G131500.1  Horvu_FT11_4H01G138300.1
# 1  Horvu_AKASHIN_1H01G302800.1  Horvu_FT11_1H01G313700.1
# 2  Horvu_AKASHIN_1H01G124100.1  Horvu_FT11_1H01G131500.1
# 3  Horvu_AKASHIN_6H01G238000.1  Horvu_FT11_6H01G255700.1
# 4  Horvu_AKASHIN_3H01G201200.1  Horvu_FT11_3H01G210800.1
#
#               Barke.fna.nucl     Golden_Promise.fna.nucl  \
# 0  Horvu_BARKE_4H01G134900.1  Horvu_GOLDEN_4H01G120100.1
# 1  Horvu_BARKE_1H01G319700.1  Horvu_GOLDEN_1H01G265800.1
# 2  Horvu_BARKE_1H01G134200.1  Horvu_GOLDEN_1H01G100100.1
# ...

# %%
## create merged ID column
df_merged['merged'] = df_merged[df_merged.columns[2:-1]].apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)

# %%
df_merged.head()
# Out:
#                           V1                           V2  \
# 0  Horvu_MOREX_4H01G139200.1  HORVU.MOREX.r2.4HG0292190.1
# 1  Horvu_MOREX_1H01G318500.1  HORVU.MOREX.r2.1HG0041620.1
# 2  Horvu_MOREX_1H01G132600.1  HORVU.MOREX.r2.1HG0016740.1
# 3  Horvu_MOREX_6H01G260800.1  HORVU.MOREX.r2.6HG0481020.1
# 4  Horvu_MOREX_3H01G206900.1  HORVU.MOREX.r2.3HG0207450.1
#
#           Akashinriki.fna.nucl        B1K-04-12.fna.nucl  \
# 0  Horvu_AKASHIN_4H01G131500.1  Horvu_FT11_4H01G138300.1
# 1  Horvu_AKASHIN_1H01G302800.1  Horvu_FT11_1H01G313700.1
# 2  Horvu_AKASHIN_1H01G124100.1  Horvu_FT11_1H01G131500.1
# 3  Horvu_AKASHIN_6H01G238000.1  Horvu_FT11_6H01G255700.1
# 4  Horvu_AKASHIN_3H01G201200.1  Horvu_FT11_3H01G210800.1
#
#               Barke.fna.nucl     Golden_Promise.fna.nucl  \
# 0  Horvu_BARKE_4H01G134900.1  Horvu_GOLDEN_4H01G120100.1
# 1  Horvu_BARKE_1H01G319700.1  Horvu_GOLDEN_1H01G265800.1
# 2  Horvu_BARKE_1H01G134200.1  Horvu_GOLDEN_1H01G100100.1
# ...

# %%
## generate gene pairs, using Morex as reference, not pair-wise comparison
# with open("tong_bhlh_pan_gene_pairs.txt","w") as f:
#     for index, row in df_merged.iterrows():
#         row_list = row["merged"].split(",")
#         for gene in row_list:
#             f.write("%s\t%s\n" % (row["Morex"], gene))

# %% [markdown]
# ## Kaks results

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## read KaKs results
kaks = "tong_bhlh_pan_gene_pairs_updated.kaks"
df_kaks = pd.read_csv(kaks,header=0,sep='\t')
df_kaks2 = df_kaks[df_kaks["Ka/Ks"] <10] ## filter kaks outlier to get more sensible results
df_kaks2.head()
# Out:
#                                           Sequence Method        Ka        Ks  \
# 0  Horvu_MOREX_1H01G060300-Horvu_10350_1H01G060200     MA  0.016318  0.089039
# 1  Horvu_MOREX_1H01G060300-Horvu_10350_1H01G113900     MA  0.042482  0.235891
# 2  Horvu_MOREX_1H01G060300-Horvu_13821_1H01G109700     MA  0.043135  0.187100
# 3  Horvu_MOREX_1H01G060300-Horvu_13942_1H01G052600     MA  0.017841  0.102323
# 4  Horvu_MOREX_1H01G060300-Horvu_13942_1H01G108000     MA  0.036793  0.208523
#
#       Ka/Ks  P-Value(Fisher)  Length   S-Sites  N-Sites  Fold-Sites(0:2:4)  \
# 0  0.183263     9.753380e-04     657   99.7802  557.220                NaN
# 1  0.180090     1.242660e-07     657   97.8333  559.167                NaN
# 2  0.230547     1.378490e-05     657   99.6907  557.309                NaN
# 3  0.174356     8.824250e-05     657  103.1180  553.882                NaN
# 4  0.176447     2.939250e-07     657  101.3550  555.645                NaN
#
# ...

# %%
##split gene pair IDs into two columns: gene1, gene2
df_kaks2[['gene1', 'gene2']] = df_kaks2['Sequence'].str.split('-', expand=True)
# Out:
# /opt/anaconda3/envs/jupyter_seaborn/lib/python3.7/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df_kaks2.head()
# Out:
#                                           Sequence Method        Ka        Ks  \
# 0  Horvu_MOREX_1H01G060300-Horvu_10350_1H01G060200     MA  0.016318  0.089039
# 1  Horvu_MOREX_1H01G060300-Horvu_10350_1H01G113900     MA  0.042482  0.235891
# 2  Horvu_MOREX_1H01G060300-Horvu_13821_1H01G109700     MA  0.043135  0.187100
# 3  Horvu_MOREX_1H01G060300-Horvu_13942_1H01G052600     MA  0.017841  0.102323
# 4  Horvu_MOREX_1H01G060300-Horvu_13942_1H01G108000     MA  0.036793  0.208523
#
#       Ka/Ks  P-Value(Fisher)  Length   S-Sites  N-Sites  Fold-Sites(0:2:4)  \
# 0  0.183263     9.753380e-04     657   99.7802  557.220                NaN
# 1  0.180090     1.242660e-07     657   97.8333  559.167                NaN
# 2  0.230547     1.378490e-05     657   99.6907  557.309                NaN
# 3  0.174356     8.824250e-05     657  103.1180  553.882                NaN
# 4  0.176447     2.939250e-07     657  101.3550  555.645                NaN
#
# ...

# %%
## use groupby to calcumate mean KaKs for each bHLH gene OG
df_kaks_mean = df_kaks2.groupby("gene1").mean()
df_kaks_mean.head()
# Out:
#                                Ka        Ks     Ka/Ks  P-Value(Fisher)  \
# gene1
# Horvu_MOREX_1H01G060300  0.028316  0.157847  0.189355         0.004338
# Horvu_MOREX_1H01G111500  0.007526  0.010522  0.696725         0.165351
# Horvu_MOREX_1H01G117100  0.001032  0.004305  0.241802         0.011452
# Horvu_MOREX_1H01G132600  0.000720  0.005730  0.127315         0.000017
# Horvu_MOREX_1H01G159400  0.004034  0.007328  0.550500         0.116295
#
#                           Length     S-Sites      N-Sites  Fold-Sites(0:2:4)  \
# gene1
# Horvu_MOREX_1H01G060300   652.75  100.591725   552.158292                NaN
# Horvu_MOREX_1H01G111500   555.00  102.060433   452.939333                NaN
# Horvu_MOREX_1H01G117100  1491.00  303.711857  1187.289286                NaN
# Horvu_MOREX_1H01G132600  1929.00  417.914750  1511.083125                NaN
# Horvu_MOREX_1H01G159400   636.00  142.290000   493.710000                NaN
#
# ...

# %%
df_match = pd.read_csv("tongcen_bhlh_v2_id_list_match_panMorex.txt",delim_whitespace=True,header=None)
#df_match = df_match.astype("str")
df_match = df_match.replace("\.1$","",regex=True) ## remove transcript id
df_match.columns = ["V1","V2"]
df_match.head()
# Out:
#                         V1                         V2
# 0  Horvu_MOREX_4H01G139200  HORVU.MOREX.r2.4HG0292190
# 1  Horvu_MOREX_1H01G318500  HORVU.MOREX.r2.1HG0041620
# 2  Horvu_MOREX_1H01G132600  HORVU.MOREX.r2.1HG0016740
# 3  Horvu_MOREX_6H01G260800  HORVU.MOREX.r2.6HG0481020
# 4  Horvu_MOREX_3H01G206900  HORVU.MOREX.r2.3HG0207450

# %%
## only use those bHLH genes with domseq >30aa
df_seq30aa = pd.read_csv("domseq.id.txt",header=None)
df_seq30aa.columns = ["seqV2"]
df_seq30aa.head()
# Out:
#                        seqV2
# 0  HORVU.MOREX.r2.1HG0007340
# 1  HORVU.MOREX.r2.1HG0013700
# 2  HORVU.MOREX.r2.1HG0014420
# 3  HORVU.MOREX.r2.1HG0016740
# 4  HORVU.MOREX.r2.1HG0020410

# %%
df_seq30aa.shape
# Out:
# (155, 1)

# %%
## match V2 IDs with pan Morex IDs
df_merged2 = df_match.merge(df_seq30aa,left_on="V2",right_on="seqV2",how="left")
df_merged2 = df_merged2.merge(df_kaks_mean,left_on="V1",right_index=True,how="left")
df_merged2.head()
# Out:
#                         V1                         V2  \
# 0  Horvu_MOREX_4H01G139200  HORVU.MOREX.r2.4HG0292190
# 1  Horvu_MOREX_1H01G318500  HORVU.MOREX.r2.1HG0041620
# 2  Horvu_MOREX_1H01G132600  HORVU.MOREX.r2.1HG0016740
# 3  Horvu_MOREX_6H01G260800  HORVU.MOREX.r2.6HG0481020
# 4  Horvu_MOREX_3H01G206900  HORVU.MOREX.r2.3HG0207450
#
#                        seqV2        Ka        Ks     Ka/Ks  P-Value(Fisher)  \
# 0  HORVU.MOREX.r2.4HG0292190  0.001027  0.001530  0.671155         0.485169
# 1  HORVU.MOREX.r2.1HG0041620       NaN       NaN       NaN              NaN
# 2  HORVU.MOREX.r2.1HG0016740  0.000720  0.005730  0.127315         0.000017
# 3  HORVU.MOREX.r2.6HG0481020  0.000557  0.003404  0.143796         0.064200
# 4  HORVU.MOREX.r2.3HG0207450  0.000890  0.001675  0.559878         0.401655
#
#    Length     S-Sites      N-Sites  ...  Substitutions  S-Substitutions  \
# 0  2661.0  539.607000  2121.390000  ...       3.000000         0.824503
# ...

# %%
cols = ["V1","V2","Ka","Ks","Ka/Ks","P-Value(Fisher)","Length","Substitutions","S-Substitutions","N-Substitutions"]

# %%
## remove empty rows and sort out column order
df_merged2 = df_merged2[df_merged2["seqV2"].notna()][cols]

# %%
## add transcript id back
df_merged2["V2"] = df_merged2["V2"].astype("str") + ".1"

# %%
df_merged2.head()
# Out:
#                         V1                           V2        Ka        Ks  \
# 0  Horvu_MOREX_4H01G139200  HORVU.MOREX.r2.4HG0292190.1  0.001027  0.001530
# 1  Horvu_MOREX_1H01G318500  HORVU.MOREX.r2.1HG0041620.1       NaN       NaN
# 2  Horvu_MOREX_1H01G132600  HORVU.MOREX.r2.1HG0016740.1  0.000720  0.005730
# 3  Horvu_MOREX_6H01G260800  HORVU.MOREX.r2.6HG0481020.1  0.000557  0.003404
# 4  Horvu_MOREX_3H01G206900  HORVU.MOREX.r2.3HG0207450.1  0.000890  0.001675
#
#       Ka/Ks  P-Value(Fisher)  Length  Substitutions  S-Substitutions  \
# 0  0.671155         0.485169  2661.0       3.000000         0.824503
# 1       NaN              NaN     NaN            NaN              NaN
# 2  0.127315         0.000017  1929.0       3.375000         2.309575
# 3  0.143796         0.064200  1914.0       2.187500         1.386953
# 4  0.559878         0.401655  1854.0       2.066667         0.909318
#
#    N-Substitutions
# 0         2.175500
# 1              NaN
# 2         1.065426
# ...

# %%
#df_merged.to_csv("tong_bhlh_pan_gene_pairs_updated.kaks.mean.treeSeq.csv",index=False)

# %% [markdown]
# ## Compare KaKs between core and dispensable bHLH gene

# %%
## read GRR results
df_GRR = pd.read_csv("MOREX_gene_GRR.txt",header=None,sep=" ")
df_GRR.columns = ["V2","GRR"]
df_GRR.head()
# Out:
#                            V2  GRR
# 0  HORVU_MOREXr2_7HG0620900.1   20
# 1  HORVU_MOREXr2_4HG0278310.1   20
# 2  HORVU_MOREXr2_5HG0441410.1   20
# 3  HORVU_MOREXr2_4HG0292190.1   20
# 4  HORVU_MOREXr2_1HG0041620.1   20

# %%
## GRR results gene IDs derived from CD-HITs parsing, need to be modifed to match with orginal gene IDs in KaKs data
df_GRR["V2"] = df_GRR["V2"].str.replace("MOREXr2","MOREX_r2")
df_GRR["V2"] = df_GRR["V2"].str.replace("_",".")
df_GRR.head()
# Out:
#                             V2  GRR
# 0  HORVU.MOREX.r2.7HG0620900.1   20
# 1  HORVU.MOREX.r2.4HG0278310.1   20
# 2  HORVU.MOREX.r2.5HG0441410.1   20
# 3  HORVU.MOREX.r2.4HG0292190.1   20
# 4  HORVU.MOREX.r2.1HG0041620.1   20

# %%
## merge GRR and KaKs data
df_kaks_GRR = df_merged2.merge(df_GRR,on="V2",how="left")
df_kaks_GRR.head()
# Out:
#                         V1                           V2        Ka        Ks  \
# 0  Horvu_MOREX_4H01G139200  HORVU.MOREX.r2.4HG0292190.1  0.001027  0.001530
# 1  Horvu_MOREX_1H01G318500  HORVU.MOREX.r2.1HG0041620.1       NaN       NaN
# 2  Horvu_MOREX_1H01G132600  HORVU.MOREX.r2.1HG0016740.1  0.000720  0.005730
# 3  Horvu_MOREX_6H01G260800  HORVU.MOREX.r2.6HG0481020.1  0.000557  0.003404
# 4  Horvu_MOREX_3H01G206900  HORVU.MOREX.r2.3HG0207450.1  0.000890  0.001675
#
#       Ka/Ks  P-Value(Fisher)  Length  Substitutions  S-Substitutions  \
# 0  0.671155         0.485169  2661.0       3.000000         0.824503
# 1       NaN              NaN     NaN            NaN              NaN
# 2  0.127315         0.000017  1929.0       3.375000         2.309575
# 3  0.143796         0.064200  1914.0       2.187500         1.386953
# 4  0.559878         0.401655  1854.0       2.066667         0.909318
#
#    N-Substitutions   GRR
# 0         2.175500  20.0
# 1              NaN  20.0
# ...

# %%
## check missing kaks rows
df_kaks_GRR[df_kaks_GRR["GRR"].isna()]
# Out:
#                           V1                           V2        Ka        Ks  \
# 129  Horvu_MOREX_7H01G304900  HORVU.MOREX.r2.7HG0564440.1  0.050759  0.196829
# 131  Horvu_MOREX_1H01G060300  HORVU.MOREX.r2.1HG0007340.1  0.028316  0.157847
# 148  Horvu_MOREX_Un01G008300  HORVU.MOREX.r2.UnG0625060.1  0.347651  0.696136
# 149  Horvu_MOREX_6H01G107500  HORVU.MOREX.r2.6HG0459840.1  0.047565  0.103772
#
#         Ka/Ks  P-Value(Fisher)      Length  Substitutions  S-Substitutions  \
# 129  0.294618         0.011223  598.525424      37.169492        14.882171
# 131  0.189355         0.004338  652.750000      26.708333        13.386461
# 148  0.449081         0.043395  414.477273      96.454545        32.787408
# 149  0.452343         0.197430  333.411765      16.248366         5.660431
#
#      N-Substitutions  GRR
# 129        22.287313  NaN
# 131        13.321873  NaN
# 148        63.667150  NaN
# 149        10.587937  NaN

# %%
## divide bHLHs into core and disposable based on GRR using pandas cut function
df_kaks_GRR["class"] = pd.cut(
    x=df_kaks_GRR["GRR"],
    bins=[1, 19, np.inf], ## change P19 to core
    labels=["dispensable", "core"],
)

# %%
## quick check GRR distribution
plt.hist(df_kaks_GRR.GRR,bins=5)
plt.show()

# %%
df_kaks_GRR.groupby("GRR").size()
# Out:
# GRR
# 7.0       1
# 11.0      1
# 12.0      1
# 15.0      1
# 16.0      1
# 17.0      1
# 18.0      1
# 19.0      7
# 20.0    137
# dtype: int64

# %%
df_kaks_GRR.head()
# Out:
#                         V1                           V2        Ka        Ks  \
# 0  Horvu_MOREX_4H01G139200  HORVU.MOREX.r2.4HG0292190.1  0.001027  0.001530
# 1  Horvu_MOREX_1H01G318500  HORVU.MOREX.r2.1HG0041620.1       NaN       NaN
# 2  Horvu_MOREX_1H01G132600  HORVU.MOREX.r2.1HG0016740.1  0.000720  0.005730
# 3  Horvu_MOREX_6H01G260800  HORVU.MOREX.r2.6HG0481020.1  0.000557  0.003404
# 4  Horvu_MOREX_3H01G206900  HORVU.MOREX.r2.3HG0207450.1  0.000890  0.001675
#
#       Ka/Ks  P-Value(Fisher)  Length  Substitutions  S-Substitutions  \
# 0  0.671155         0.485169  2661.0       3.000000         0.824503
# 1       NaN              NaN     NaN            NaN              NaN
# 2  0.127315         0.000017  1929.0       3.375000         2.309575
# 3  0.143796         0.064200  1914.0       2.187500         1.386953
# 4  0.559878         0.401655  1854.0       2.066667         0.909318
#
#    N-Substitutions   GRR class
# 0         2.175500  20.0  core
# ...

# %% [markdown]
# ## original KaKs without filtering

# %%
fig,axs=plt.subplots(1,3,figsize=(10,6))

# sns.barplot(x="class",y="Ka/Ks",data=df_kaks_grr[df_kaks_grr["Ka/Ks"]<10],\
#         capsize=0.05,)

sns.boxplot(ax= axs[0], x="class",y="Ka",data=df_kaks_grr)
sns.boxplot(ax= axs[1], x="class",y="Ks",data=df_kaks_grr)
sns.boxplot(ax=axs[2], x="class",y="Ka/Ks",data=df_kaks_grr)
#ax.set_xticklabels(["Background","Target"],fontsize=12)
#ax.set_yticklabels(fontsize=8)

# fig.suptitle('pangenome ortholog comparison', fontsize=20)
# plt.ylabel('Ka/Ks',fontsize=20)
# plt.xlabel('Gene retention number', fontsize=20)

# change bar width
# for i in range(0,3):
#     for bar in axs[i].patches:
#         x = bar.get_x()
#         width = bar.get_width()
#         centre = x+width/2.

#         newwidth = 0.5

#         bar.set_x(centre-newwidth/2.)
#         bar.set_width(newwidth)

# add a horizontal line
#kwargs={"color":"red","linewidth":1,"linestyle":"--"}
#ax.axhline(1.0,**kwargs)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Filter KaKs < 10 before computing mean kaks

# %% [markdown]
# ### boxplots

# %%
fig,axs=plt.subplots(1,3,figsize=(10,6))

# sns.barplot(x="class",y="Ka/Ks",data=df_kaks_grr[df_kaks_grr["Ka/Ks"]<10],\
#         capsize=0.05,)

sns.boxplot(ax= axs[0], x="class",y="Ka",data=df_kaks_GRR)
axs[0].set_ylim(0,0.145)
axs[0].set_xticklabels(["Dispensable","Core"])
axs[0].set_xlabel("")

sns.boxplot(ax= axs[1], x="class",y="Ks",data=df_kaks_GRR)
axs[1].set_ylim(0,0.5)
axs[1].set_xticklabels(["Dispensable","Core"])
axs[1].set_xlabel("")

sns.boxplot(ax=axs[2], x="class",y="Ka/Ks",data=df_kaks_GRR)
axs[2].set_xlabel("")
axs[2].set_xticklabels(["Dispensable","Core"])


# for bar in fig.patches:
#         x = bar.get_x()
#         width = bar.get_width()
#         centre = x+width/2.

#         newwidth = 0.2

#         bar.set_x(centre-newwidth/2.)
#         bar.set_width(newwidth)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### violin plot

# %%
colors = sns.color_palette()

# %%
fig,axs=plt.subplots(1,3,figsize=(12,4))

# sns.barplot(x="class",y="Ka/Ks",data=df_kaks_grr[df_kaks_grr["Ka/Ks"]<10],\
#         capsize=0.05,)

sns.violinplot(ax= axs[0], x="class",y="Ka",data=df_kaks_GRR)
#axs[0].set_ylim(0,0.145)
axs[0].set_xticklabels(["Dispensable","Core"], fontsize=12)
axs[0].set_xlabel("")
axs[0].set_ylabel("Ka", fontsize=15)

sns.violinplot(ax= axs[1], x="class",y="Ks",data=df_kaks_GRR)
#axs[1].set_ylim(0,0.5)
axs[1].set_xticklabels(["Dispensable","Core"],fontsize=12)
axs[1].set_xlabel("")
axs[1].set_ylabel("Ks", fontsize=15)

sns.violinplot(ax=axs[2], x="class",y="Ka/Ks",data=df_kaks_GRR)
axs[2].set_xlabel("")
axs[2].set_ylabel("Ka/Ks", fontsize=15)
axs[2].set_xticklabels(["Dispensable","Core"], fontsize=12)

##lengds
# legends = [Patch(facecolor=colors[0], edgecolor='black',
#                          label='Core'),
#           Patch(facecolor=colors[1], edgecolor='black',
#                          label='Dispensable')]
# axs[1].legend(handles=legends, loc='upper right', bbox_to_anchor=(1, 1.15),
#              ncol=2)


plt.tight_layout()
plt.show()

# %%
## save violin plot
fig.savefig("KaKs_core_dispensable_violin_v3.png",dpi=300)

# %%
df_kaks_GRR.tail()
# Out:
#                           V1                           V2        Ka        Ks  \
# 150  Horvu_MOREX_2H01G439000  HORVU.MOREX.r2.2HG0137300.1  0.022146  0.030263
# 151  Horvu_MOREX_2H01G716700  HORVU.MOREX.r2.2HG0171350.1       NaN       NaN
# 152  Horvu_MOREX_7H01G212600  HORVU.MOREX.r2.7HG0552630.1       NaN       NaN
# 153  Horvu_MOREX_6H01G469500  HORVU.MOREX.r2.6HG0509990.1  0.000037  0.036829
# 154  Horvu_MOREX_4H01G436600  HORVU.MOREX.r2.4HG0336070.1  0.000045  0.045247
#
#         Ka/Ks  P-Value(Fisher)      Length  Substitutions  S-Substitutions  \
# 150  0.735577         0.444496  355.304348       8.173913         2.415289
# 151       NaN              NaN         NaN            NaN              NaN
# 152       NaN              NaN         NaN            NaN              NaN
# 153  0.001000         0.000000  264.000000       1.000000         0.992006
# 154  0.001000         0.000000  255.000000       1.500000         1.490067
#
#      N-Substitutions   GRR        class
# ...

# %%
CORE_kaks = df_kaks_GRR[df_kaks_GRR["class"] == "core"]["Ka/Ks"]
DISP_kaks = df_kaks_GRR[df_kaks_GRR["class"] == "dispensable"]["Ka/Ks"]

# %%
t1 = CORE_kaks[~np.isnan(CORE_kaks)].to_list()
t2 = DISP_kaks[~np.isnan(DISP_kaks)].to_list()

# %%
PAIR  = [(0, 'core'), (0, 'dispensable')]
# Out:
# [0.20615761818181816,
#  0.4890012222222222,
#  0.16574188,
#  0.15117037500000002,
#  0.1501105135135136,
#  0.384361738095238,
#  0.486461,
#  0.5595431860465117,
#  0.516425,
#  nan,
#  0.5104058019867552,
#  0.5586954333333334,
#  0.001,
#  0.7355773043478261]

# %%
## t-tests
from scipy import stats
from utils import *
import numpy as np
from scipy.stats import mannwhitneyu, normaltest
from statannotations.Annotator import Annotator

# %%
PAIR  = [('core', 'dispensable')]

# %%
fig,axs=plt.subplots(1,3,figsize=(12,4))

sns.violinplot(ax= axs[0], x="class",y="Ka",data=df_kaks_GRR)
axs[0].set_ylim(-0.1,0.38)
axs[0].set_xticklabels(["Dispensable","Core"], fontsize=12)
axs[0].set_xlabel("")
axs[0].set_ylabel("Ka", fontsize=15)
annot0 = Annotator(axs[0], PAIR,
               data=df_kaks_GRR, x="class", y="Ka")
annot0.configure(test='t-test_ind', text_format='full', loc='inside',
                comparisons_correction=None, 
                show_test_name=False,
                line_height=0.02, text_offset=8)
annot0.apply_test().annotate(line_offset_to_group=0.75, line_offset=0.5)

sns.violinplot(ax= axs[1], x="class",y="Ks",data=df_kaks_GRR)
axs[1].set_ylim(-0.3,1.5)
axs[1].set_xticklabels(["Dispensable","Core"],fontsize=12)
axs[1].set_xlabel("")
axs[1].set_ylabel("Ks", fontsize=15)
annot1 = Annotator(axs[1], PAIR,
               data=df_kaks_GRR, x="class", y="Ks")
annot1.configure(test='t-test_ind', text_format='full', loc='inside',
                comparisons_correction=None, 
                show_test_name=False,
                line_height=0.02, text_offset=8)

annot1.apply_test().annotate(line_offset_to_group=0.7, line_offset=0.5)


sns.violinplot(ax=axs[2], x="class",y="Ka/Ks",data=df_kaks_GRR)
axs[2].set_ylim(-0.3,1.75)
axs[2].set_xlabel("")
axs[2].set_ylabel("Ka/Ks", fontsize=15)
axs[2].set_xticklabels(["Dispensable","Core"], fontsize=12)
# annotator = Annotator(axs[2], PAIR, data=df_kaks_GRR, x="class", y="Ka/Ks")
# annotator.configure(test='Mann-Whitney',verbose=False,loc='inside',text_offset=8).apply_and_annotate()

annot2 = Annotator(axs[2], PAIR,
               data=df_kaks_GRR, x="class", y="Ka/Ks")
annot2.configure(test='t-test_ind', text_format='full', loc='inside',
                comparisons_correction=None, 
                show_test_name=False,
                line_height=0.02, text_offset=8)

annot2.apply_test().annotate(line_offset_to_group=0.5, line_offset=0.5)

plt.tight_layout()
plt.show()
# Out:
# dispensable vs. core: t-test independent samples, P_val:8.721e-07 t=5.156e+00
# dispensable vs. core: t-test independent samples, P_val:1.301e-03 t=3.284e+00
# dispensable vs. core: t-test independent samples, P_val:1.560e-02 t=2.449e+00

# %% [markdown]
# ### bar plots

# %%
fig,axs=plt.subplots(1,3,figsize=(10,4))
sns.barplot(ax=axs[0],x="class",y="Ka",data=df_kaks_GRR)
sns.barplot(ax=axs[1],x="class",y="Ks",data=df_kaks_GRR)
sns.barplot(ax=axs[2],x="class",y="Ka/Ks",data=df_kaks_GRR)
plt.show()

# %% [markdown]
# ## Plot kaks for different subfamilies

# %%
## read subfamily information
df_sub = pd.read_csv("subfamily_MOREX.txt", header=None,sep='\t')
df_sub.columns = ["V2","family"]
df_sub["V2"] = df_sub["V2"].str.replace("_MOREXr2_",".MOREX.r2.")
df_sub["V2"] = df_sub["V2"].str.split("-",expand=True)[0]
df_sub.head()
# Out:
#                             V2 family
# 0  HORVU.MOREX.r2.2HG0170560.1   SF12
# 1  HORVU.MOREX.r2.7HG0603720.1   SF12
# 2  HORVU.MOREX.r2.3HG0268450.1   SF12
# 3  HORVU.MOREX.r2.3HG0268430.1   SF12
# 4  HORVU.MOREX.r2.3HG0268420.1   SF12

# %%
df_kaks_GRR.head()
# Out:
#                         V1                           V2        Ka        Ks  \
# 0  Horvu_MOREX_4H01G139200  HORVU.MOREX.r2.4HG0292190.1  0.001027  0.001530
# 1  Horvu_MOREX_1H01G318500  HORVU.MOREX.r2.1HG0041620.1       NaN       NaN
# 2  Horvu_MOREX_1H01G132600  HORVU.MOREX.r2.1HG0016740.1  0.000720  0.005730
# 3  Horvu_MOREX_6H01G260800  HORVU.MOREX.r2.6HG0481020.1  0.000557  0.003404
# 4  Horvu_MOREX_3H01G206900  HORVU.MOREX.r2.3HG0207450.1  0.000890  0.001675
#
#       Ka/Ks  P-Value(Fisher)  Length  Substitutions  S-Substitutions  \
# 0  0.671155         0.485169  2661.0       3.000000         0.824503
# 1       NaN              NaN     NaN            NaN              NaN
# 2  0.127315         0.000017  1929.0       3.375000         2.309575
# 3  0.143796         0.064200  1914.0       2.187500         1.386953
# 4  0.559878         0.401655  1854.0       2.066667         0.909318
#
#    N-Substitutions   GRR class
# 0         2.175500  20.0  core
# ...

# %%
## merge kaks and subfamily data
df_kaks_GRR_sub = df_kaks_GRR.merge(df_sub,on="V2",how="left")
df_kaks_GRR_sub.head()
# Out:
#                         V1                           V2        Ka        Ks  \
# 0  Horvu_MOREX_4H01G139200  HORVU.MOREX.r2.4HG0292190.1  0.001027  0.001530
# 1  Horvu_MOREX_1H01G318500  HORVU.MOREX.r2.1HG0041620.1       NaN       NaN
# 2  Horvu_MOREX_1H01G132600  HORVU.MOREX.r2.1HG0016740.1  0.000720  0.005730
# 3  Horvu_MOREX_6H01G260800  HORVU.MOREX.r2.6HG0481020.1  0.000557  0.003404
# 4  Horvu_MOREX_3H01G206900  HORVU.MOREX.r2.3HG0207450.1  0.000890  0.001675
#
#       Ka/Ks  P-Value(Fisher)  Length  Substitutions  S-Substitutions  \
# 0  0.671155         0.485169  2661.0       3.000000         0.824503
# 1       NaN              NaN     NaN            NaN              NaN
# 2  0.127315         0.000017  1929.0       3.375000         2.309575
# 3  0.143796         0.064200  1914.0       2.187500         1.386953
# 4  0.559878         0.401655  1854.0       2.066667         0.909318
#
#    N-Substitutions   GRR class family
# 0         2.175500  20.0  core   SF28
# ...

# %%
## check unassigned subfamily gene, corresponding those bHLH domain < 30aa, which included during kaks calculation
df_kaks_GRR_sub[df_kaks_GRR_sub.family.isna()]
# Out:
#                           V1                           V2        Ka        Ks  \
# 129  Horvu_MOREX_7H01G304900  HORVU.MOREX.r2.7HG0564440.1  0.050759  0.196829
# 131  Horvu_MOREX_1H01G060300  HORVU.MOREX.r2.1HG0007340.1  0.028316  0.157847
# 148  Horvu_MOREX_Un01G008300  HORVU.MOREX.r2.UnG0625060.1  0.347651  0.696136
# 149  Horvu_MOREX_6H01G107500  HORVU.MOREX.r2.6HG0459840.1  0.047565  0.103772
#
#         Ka/Ks  P-Value(Fisher)      Length  Substitutions  S-Substitutions  \
# 129  0.294618         0.011223  598.525424      37.169492        14.882171
# 131  0.189355         0.004338  652.750000      26.708333        13.386461
# 148  0.449082         0.043395  414.477273      96.454545        32.787408
# 149  0.452343         0.197430  333.411765      16.248366         5.660431
#
#      N-Substitutions  GRR class family
# 129        22.287313  NaN   NaN    NaN
# 131        13.321873  NaN   NaN    NaN
# 148        63.667150  NaN   NaN    NaN
# 149        10.587937  NaN   NaN    NaN

# %%
## check number of gene for each subfamily, the current subfamily data does not include new bHLH genes,
## thus is lower than table 1 in manuscript
df_kaks_GRR_sub.groupby("family").size()
# Out:
# family
# SF01       15
# SF02        8
# SF03        9
# SF04        7
# SF05        3
# SF07        6
# SF08        1
# SF09        3
# SF10        9
# SF11        1
# SF12        5
# SF13       10
# SF14        3
# SF15        7
# SF16        4
# SF24       10
# SF25       13
# SF26        5
# SF27        5
# SF28       10
# SF31        9
# SF_like     8
# dtype: int64

# %%
## Boxplot
fig,axs=plt.subplots(3,1,figsize=(10,8),sharex=True)

sns.boxplot(ax= axs[0], x="family",y="Ka",data=df_kaks_GRR_sub)
axs[0].set_ylim(0,0.04)
#axs[0].set_xticklabels(["Dispensable","Core"])
axs[0].set_xlabel("")

sns.boxplot(ax= axs[1], x="family",y="Ks",data=df_kaks_GRR_sub)
axs[1].set_ylim(0,0.1)
#axs[1].set_xticklabels(["Dispensable","Core"])
axs[1].set_xlabel("")

sns.boxplot(ax=axs[2], x="family",y="Ka/Ks",data=df_kaks_GRR_sub)
axs[2].set_ylim(0,1.21)
axs[2].set_xlabel("")
LABELS = axs[2].get_xticklabels()
axs[2].set_xticklabels(LABELS, rotation=90)

plt.tight_layout()
plt.show()

# %%
## violinplot
fig,axs=plt.subplots(3,1,figsize=(10,8),sharex=True)

sns.violinplot(ax= axs[0], x="family",y="Ka",data=df_kaks_GRR_sub)
axs[0].set_ylim(0,0.04)
#axs[0].set_xticklabels(["Dispensable","Core"])
axs[0].set_xlabel("")

sns.violinplot(ax= axs[1], x="family",y="Ks",data=df_kaks_GRR_sub)
axs[1].set_ylim(0,0.1)
#axs[1].set_xticklabels(["Dispensable","Core"])
axs[1].set_xlabel("")

sns.violinplot(ax=axs[2], x="family",y="Ka/Ks",data=df_kaks_GRR_sub)
axs[2].set_ylim(0,1.21)
axs[2].set_xlabel("")
LABELS = axs[2].get_xticklabels()
axs[2].set_xticklabels(LABELS, rotation=90)


plt.tight_layout()
plt.show()

# %%
## barplot
fig,axs=plt.subplots(3,1,figsize=(10,8),sharex=True)

sns.barplot(ax= axs[0], x="family",y="Ka",data=df_kaks_GRR_sub)
#axs[0].set_ylim(0,0.04)
#axs[0].set_xticklabels(["Dispensable","Core"])
axs[0].set_xlabel("")

sns.barplot(ax= axs[1], x="family",y="Ks",data=df_kaks_GRR_sub)
#axs[1].set_ylim(0,0.1)
#axs[1].set_xticklabels(["Dispensable","Core"])
axs[1].set_xlabel("")

sns.barplot(ax=axs[2], x="family",y="Ka/Ks",data=df_kaks_GRR_sub)
#axs[2].set_ylim(0,1.21)
axs[2].set_xlabel("")
LABELS = axs[2].get_xticklabels()
axs[2].set_xticklabels(LABELS, rotation=90)

plt.tight_layout()
plt.show()

# %%
ERR_ka = df_kaks_GRR_sub.groupby("family")["Ka"].describe()["std"]
ERR_ks = df_kaks_GRR_sub.groupby("family")["Ks"].describe()["std"]
ERR_kaks = df_kaks_GRR_sub.groupby("family")["Ka/Ks"].describe()["std"]

# %%
AV_ka = df_kaks_GRR_sub.groupby("family")["Ka"].describe()["mean"]
AV_ks = df_kaks_GRR_sub.groupby("family")["Ks"].describe()["mean"]
AV_kaks = df_kaks_GRR_sub.groupby("family")["Ka/Ks"].describe()["mean"]

# %%
Order = [x.get_text() for x in LABELS]
Order
# Out:
# ['SF28',
#  'SF02',
#  'SF05',
#  'SF07',
#  'SF25',
#  'SF01',
#  'SF14',
#  'SF24',
#  'SF31',
#  'SF26',
#  'SF09',
#  'SF15',
#  'SF10',
#  'SF03',
#  'SF27',
#  'SF13',
#  'SF11',
#  'SF_like',
#  'SF04',
#  'SF12',
#  'SF08',
#  'SF16']

# %%
## sort subfamily based on AV_KAKS from high to low
Sorted = list(AV_kaks.sort_values(ascending=True).index)
Sorted
# Out:
# ['SF16',
#  'SF11',
#  'SF10',
#  'SF26',
#  'SF28',
#  'SF01',
#  'SF25',
#  'SF31',
#  'SF13',
#  'SF15',
#  'SF07',
#  'SF08',
#  'SF_like',
#  'SF27',
#  'SF14',
#  'SF05',
#  'SF02',
#  'SF04',
#  'SF03',
#  'SF24',
#  'SF12',
#  'SF09']

# %%
df_kaks_GRR_sub.groupby("family")["Ka"].describe().head()
# Out:
#         count      mean       std       min       25%       50%       75%  \
# family
# SF01     13.0  0.033358  0.076092  0.000008  0.000699  0.003274  0.003809
# SF02      7.0  0.019965  0.042328  0.000004  0.001008  0.001221  0.010789
# SF03      9.0  0.004836  0.003836  0.000348  0.003052  0.003504  0.005677
# SF04      5.0  0.045635  0.094768  0.000005  0.000024  0.005248  0.007845
# SF05      3.0  0.002358  0.001883  0.000720  0.001329  0.001938  0.003177
#
#              max
# family
# SF01    0.219704
# SF02    0.114938
# SF03    0.011585
# SF04    0.215053
# SF05    0.004416

# %%
ERR_KA = ERR_ka.reindex(index = Sorted)
ERR_KS = ERR_ks.reindex(index = Sorted)
ERR_KAKS = ERR_kaks.reindex(index = Sorted)

AV_KA = AV_ka.reindex(index = Sorted)
AV_KS = AV_ks.reindex(index = Sorted)
AV_KAKS0 = AV_kaks.reindex(index = Order)
AV_KAKS = AV_kaks.reindex(index = Sorted)

# %%
df_kaks_GRR_sub.groupby("family")["Ks"].describe()["mean"].max()
# Out:
# 0.15910934807630023

# %%
##to create legend
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# %%
## merge in a single ax
## barplot
fig,ax=plt.subplots(figsize=(15,5)) ##need to include both fig and ax, otherwise fig would = (fig,ax)

ax = sns.barplot(x="family",y="Ka",data=df_kaks_GRR_sub, ci=None)
ax.set_ylim(0,0.17)
ax.set_ylabel('Ka',fontsize=17)
ax.set_yticks(np.arange(0,0.17,0.02))
ax.set_yticklabels(np.arange(0,0.17,0.02), fontsize=12)

##change bar width
width_scale = 0.5
for bar in ax.containers[0]:
    bar.set_width(bar.get_width() * width_scale)


## get x & y positions for each bar patch, to manually add error bar
x_pos = []
y_pos = []
for patch in ax.patches:
    x_pos.append(patch.get_xy()[0]+(patch._width/2))
    y_pos.append(patch.get_height())

# ax.errorbar(x_pos, y_pos, yerr=ERR_KA,
#              marker='_', mec='blue', zorder=10, elinewidth=1, capsize=2, ecolor='blue',
#              linestyle="None", markersize=10)

ax.set_xlabel("")
ax2 = ax.twinx()
ax2 = sns.barplot(x="family",y="Ks",data=df_kaks_GRR_sub, ci=None, hatch="...")
ax2.set_ylim(0,0.17)
ax2.set_yticks(np.arange(0,0.17,0.04))
ax2.set_yticklabels(np.arange(0,0.17,0.04), fontsize=12)
#ax2.legend(["Ks"],loc='upper right', bbox_to_anchor=(1, 0.95),edgecolor="white")

ax2.set_ylabel('Ks',fontsize=17)
for bar in ax2.containers[0]:
    x = bar.get_x()
    w = bar.get_width()
    bar.set_x(x + w * (1- width_scale))
    bar.set_width(w * width_scale)

ax3 = ax.twinx()
ax3 = sns.lineplot(x="family",y="Ka/Ks",data=df_kaks_GRR_sub, marker='o', sort = False, color="red",ci=85)
ax3.set_yticks(())
ax3.set_ylabel('')

for i, kaks in enumerate (AV_KAKS0):
    val='{0:.1f}'. format(kaks)
    ax3.annotate(val,(Order[i],kaks+0.03),fontsize=10)

LABELS = ax.get_xticklabels()
ax.set_xticklabels(LABELS, rotation=60,fontsize=15)

###add customer legend
legends = [Patch(facecolor='white', edgecolor='black',
                         label='Ka'),
          Patch(facecolor='white', edgecolor='black',
                         label='Ks',hatch="..."),
          Line2D([0], [0], marker='o', color='r', label='Ka/Ks',
                          markerfacecolor='r', markersize=6)]
ax.legend(handles=legends, loc='upper right', bbox_to_anchor=(1, 1))

fig.tight_layout()
plt.show()

# %%
type(fig)
# Out:
# tuple

# %%
fig.savefig("kaks_groupby_subfamily.png",dpi=300,bbox_inches='tight')

# %%
df_kaks_GRR_sub.groupby("family")["Ka"].describe().head()
# Out:
#         count      mean       std       min       25%       50%       75%  \
# family
# SF01     13.0  0.033358  0.076092  0.000008  0.000699  0.003274  0.003809
# SF02      7.0  0.019965  0.042328  0.000004  0.001008  0.001221  0.010789
# SF03      9.0  0.004836  0.003836  0.000348  0.003052  0.003504  0.005677
# SF04      5.0  0.045635  0.094768  0.000005  0.000024  0.005248  0.007845
# SF05      3.0  0.002358  0.001883  0.000720  0.001329  0.001938  0.003177
#
#              max
# family
# SF01    0.219704
# SF02    0.114938
# SF03    0.011585
# SF04    0.215053
# SF05    0.004416

# %%
AV_KA
# Out:
# family
# SF16       0.000041
# SF11       0.000735
# SF10       0.001450
# SF26       0.001065
# SF28       0.000959
# SF01       0.033358
# SF25       0.001024
# SF31       0.001533
# SF13       0.005754
# SF15       0.001459
# SF07       0.001256
# SF08       0.002711
# SF_like    0.003856
# SF27       0.007057
# SF14       0.001182
# SF05       0.002358
# SF02       0.019965
# SF04       0.045635
# SF03       0.004836
# SF24       0.003517
# SF12       0.006629
# SF09       0.004999
# Name: mean, dtype: float64

# %%
## manipulate error bar or error band in lineplot
# https://stackoverflow.com/questions/56203420/how-to-use-custom-error-bar-in-seaborn-lineplot

# %%
## sorted according to KaKs
## merge in a single ax
## barplot
fig=plt.subplots(figsize=(15,5))

ax = sns.barplot(x=Sorted,y=AV_KA, ci=None)
ax.set_ylim(0,0.17)
ax.set_ylabel('Ka',fontsize=15)
ax.set_yticks(np.arange(0,0.17,0.02))
ax.set_yticklabels(np.arange(0,0.17,0.02), fontsize=12)

##change bar width
width_scale = 0.5
for bar in ax.containers[0]:
    bar.set_width(bar.get_width() * width_scale)

ax_xpos = [bar.get_x() for bar in ax.containers[0]]
ax.errorbar([x+0.2 for x in ax_xpos], AV_KA, ERR_KA, color='black', linestyle='', elinewidth=0.5)

## get x & y positions for each bar patch, to manually add error bar
x_pos = []
y_pos = []
for patch in ax.patches:
    x_pos.append(patch.get_xy()[0]+(patch._width/2))
    y_pos.append(patch.get_height())

# ax.errorbar(x_pos, y_pos, yerr=ERR_KA,
#              marker='_', mec='blue', zorder=10, elinewidth=1, capsize=2, ecolor='blue',
#              linestyle="None", markersize=10)

ax.set_xlabel("")
ax2 = ax.twinx()
ax2 = sns.barplot(x=Sorted,y=AV_KS, hatch="...")
ax2.set_ylim(0,0.17)
ax2.set_yticks(np.arange(0,0.17,0.04))
ax2.set_yticklabels(np.arange(0,0.17,0.04), fontsize=12)

ax2.set_ylabel('Ks',fontsize=15)

ax2_xpos = []
for bar in ax2.containers[0]:
    x = bar.get_x()
    w = bar.get_width()
    bar.set_x(x + w * (1- width_scale))
    bar.set_width(w * width_scale)
    ax2_xpos.append(x) ##geting bar position

###add errorbar
ax2.errorbar([x+0.6 for x in ax2_xpos], AV_KS, ERR_KS, color='black', linestyle='', elinewidth=0.5,\
            capsize=0.5)

ax3 = ax.twinx()
ax3 = sns.lineplot(x=Sorted,y=AV_KAKS, marker='o', sort = False, color="red")
#ax3 = sns.lineplot(x=ax2_xpos,y=AV_KAKS, marker='o', sort = False, color="red")
ax3.set_yticks(())
ax3.set_ylabel('')


for i, kaks in enumerate (AV_KAKS):
    val='{0:.1f}'. format(kaks)
    ax3.annotate(val,(Sorted[i],kaks+0.03),fontsize=10)
ax3.annotate(0.5,("SF09",AV_KAKS[-1]-0.03),fontsize=10)

LABELS = ax.get_xticklabels()
ax.set_xticklabels(LABELS, rotation=60,fontsize=15)

plt.tight_layout()
plt.show()

# %%
ax2_xpos
# Out:
# [-0.4,
#  0.6,
#  1.6,
#  2.6,
#  3.6,
#  4.6,
#  5.6,
#  6.6,
#  7.6,
#  8.6,
#  9.6,
#  10.6,
#  11.6,
#  12.6,
#  13.6,
#  14.6,
#  15.6,
#  16.6,
#  17.6,
#  18.6,
#  19.6,
#  20.6]

# %%
data = {'Candidate': ['X', 'Y', 'Z', 'X', 'Y', 'Z', 'X', 'Y', 'Z'],
        'Sample_Set': [1, 1, 1, 2, 2, 2, 3, 3, 3],
        'Values': [20, 10, 10, 200, 101, 99, 1999, 998, 1003],
        'Error': [5, 2, 3, 30, 30, 30, 10, 10, 10]}
df_test = pd.DataFrame(data)
display(df_test)
# Out:
#   Candidate  Sample_Set  Values  Error
# 0         X           1      20      5
# 1         Y           1      10      2
# 2         Z           1      10      3
# 3         X           2     200     30
# 4         Y           2     101     30
# 5         Z           2      99     30
# 6         X           3    1999     10
# 7         Y           3     998     10
# 8         Z           3    1003     10

# %%
cat = "Candidate"
subcat = "Sample_Set"
val = "Values"
err = "Error"
u = df_test[cat].unique()
x = np.arange(len(u))
subx = df_test[subcat].unique()
offsets = (np.arange(len(subx))-np.arange(len(subx)).mean())/(len(subx)+1.)
width= np.diff(offsets).mean()
for i,gr in enumerate(subx):
        dfg = df_test[df_test[subcat] == gr]
        plt.bar(x+offsets[i], dfg[val].values, width=width, 
                label="{} {}".format(subcat, gr), yerr=dfg[err].values)
plt.xlabel(cat)
plt.ylabel(val)
plt.xticks(x, u)
plt.legend()
plt.show()

# %%
x
# Out:
# array([0, 1, 2])

# %%
for i in range():
    print(x+offsets[1])
# Out:
# array([0., 1., 2.])

# %%
simulated_data = pd.DataFrame({
        'condition': ['A']*4 + ['B']*4,
        'Protein': ['w', 'x', 'y', 'z']*2,
        'data': np.random.uniform(10, 11, 8)
    })
simulated_data.head()
# Out:
#   condition Protein       data
# 0         A       w  10.773535
# 1         A       x  10.112300
# 2         A       y  10.314593
# 3         A       z  10.464271
# 4         B       w  10.343447

# %%
for i, kaks in enumerate (AV_KAKS):
    print(i, kaks)
# Out:
# 0 0.12502893930555556
# 1 0.3182239867100046
# 2 0.3103536694688109
# 3 0.1912911583333333
# 4 0.15506036016277325
# 5 0.15301067824517622
# 6 0.27440258484848484
# 7 0.38753699804023134
# 8 0.1584963865556146
# 9 0.11816469822222223
# 10 0.48625920617647067
# 11 0.168803233126584
# 12 0.09571862976761077
# 13 0.3807395224879596
# 14 0.26585472020460355
# 15 0.16339265824610213
# 16 0.0815755722222222
# 17 0.2184357384895833
# 18 0.3210588705882352
# 19 0.4268964053015873
# 20 0.210923
# 21 0.001

# %%
def scatter_hist(x, y, ax, ax_histx, ax_histy):
    # no labels
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)

    # the scatter plot:
    ax.scatter(x, y)

    # now determine nice limits by hand:
    xymax = max(np.max(np.abs(x)), np.max(np.abs(y)))
    numbin = 10
    binwidth = xymax/numbin
    #lim = (int(xymax/binwidth) + 1) * binwidth
    lim = xymax + binwidth

    bins = np.arange(0, lim, binwidth)
    ax_histx.hist(x, bins=bins)
    ax_histy.hist(y, bins=bins, orientation='horizontal')

# %%
# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
rect_histy = [left + width + spacing, bottom, 0.2, height]

# start with a square Figure
fig = plt.figure(figsize=(8, 8))

ax = fig.add_axes(rect_scatter)
ax_histx = fig.add_axes(rect_histx, sharex=ax)
ax_histy = fig.add_axes(rect_histy, sharey=ax)

# use the previously defined function
scatter_hist(df.Ka, df.Ks, ax, ax_histx, ax_histy)

plt.show()

# %%
sns.__version__
# Out:
# '0.9.0'

# %%
plt.boxplot
