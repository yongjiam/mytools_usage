# %%
### Previous step: Align assembly genomes
##extract and modify the name of fasta sequences
#seqkit sort -l -r -i S1_hifi.asm.bp.p_ctg.fa|seqkit head -n 26 |seqkit replace -p .+ -r 'S1_{nr}' -o S1_min1M_rename.fasta
## minimap2 -t 128 -x asm5 /scratch/pawsey0399/bguo1/0.assembly/01.hifi_assembly/S2_HIFI_RESULT/S2_hifi.asm.bp.p_ctg.fa /scratch/pawsey0399/bguo1/0.assembly/01.hifi_assembly/S1_HIFI_RESULT/S1_hifi.asm.bp.p_ctg.fa >S1_TO_S2.paf

# Load necessary libraries
library(pafr,quietly=TRUE)      # For handling PAF (Pairwise mApping Format) files
library(patchwork,quietly=TRUE) # For creating composite plots
library(tidyverse,quietly=TRUE) # For data manipulation and visualization
# Out:
# ── Attaching core tidyverse packages ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ lubridate 1.9.3     ✔ tibble    3.2.1
# ✔ purrr     1.0.2     ✔ tidyr     1.3.1
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %% [markdown]
# # hap1 and hap2 ragtag outputs

# %%
# Set the plot size
options(repr.plot.width=10, repr.plot.height=10)  # Adjust width and height as needed

hap1 <- read_paf("output_sed_hap1/ragtag.scaffold.asm.paf")
dotplot(hap1,label_seqs = TRUE,order_by="qstart", alignment_colour="blue")
# Out:
# plot without title

# %%
# Set the plot size
options(repr.plot.width=10, repr.plot.height=10)  # Adjust width and height as needed

hap2 <- read_paf("output_sed_hap2/ragtag.scaffold.asm.paf")
dotplot(hap2,label_seqs = TRUE,order_by="qstart", alignment_colour="red")
# Out:
# plot without title

# %% [markdown]
# # hap1 and hap2 scaffolds outputs aligned to genome.fa

# %%
# Set the plot size
options(repr.plot.width=10, repr.plot.height=10)  # Adjust width and height as needed

hap1scaf <- read_paf("output_sed_hap1/hap1_aln.paf")
dotplot(hap1scaf,label_seqs = TRUE,order_by="qstart", alignment_colour="blue")
# Out:
# plot without title

# %%
# Set the plot size
options(repr.plot.width=10, repr.plot.height=10)  # Adjust width and height as needed

hap2scaf <- read_paf("output_sed_hap2/hap2_aln.paf")
dotplot(hap2scaf,label_seqs = TRUE,order_by="qstart", alignment_colour="red")
# Out:
# plot without title

# %% [markdown]
# # sort chromosome order

# %%
# Set the plot size
options(repr.plot.width=10, repr.plot.height=10)  # Adjust width and height as needed

hap1 <- read_paf("swo_hap1_minimap.paf")
dotplot(hap1,label_seqs = TRUE,order_by='provided',
        ordering= list(c("H1_ch6", "H1_ch2", "H1_ch3", "H1_ch5", "H1_ch1", "H1_ch7", "H1_ch4", "H1_ch8", "H1_ch9"),
        c("chr1","chr2","chr3","chr4","chr5","chr6","chr7","chr8","chr9")),
        alignment_colour="blue")
# Out:
# Warning message:
# “Dropping data from sequences absent from ordering:
#  chrUn”
# plot without title

# %%
# Read the PAF file into a data frame
hap2 <- read_paf("hap2_swo_minimap.paf")
plot2 <- dotplot(hap2,label_seqs = TRUE,order_by="qstart", alignment_colour="purple")
ggsave("hap2_swo_dotplot.png", plot2, width = 6, height = 6)

# %%
# Create a dotplot visualization from the PAF data
dotplot(df, order_by='provided',
        ordering= list(c("H2_ch1","H2_ch2","H2_ch3","H2_ch4","H2_ch5","H2_ch6","H2_ch7","H2_ch8","H2_ch9"),
        c("H1_ch1","H1_ch2","H1_ch3","H1_ch4","H1_ch5","H1_ch6","H1_ch7","H1_ch8","H1_ch9")),
        label_seqs = TRUE)
# Out:
# plot without title

# %%
# Create a dotplot visualization from the PAF data
dotplot(df, label_seqs = TRUE)
# Out:
# plot without title

# %% [markdown]
# # separate chromosomes

# %%
library(gridExtra)
# Out:
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine

# %% [markdown]
# ### Hap1_genome.aln

# %%
# load paf data

df1 <- read_paf("output_sed_hap1/hap1_aln.paf")

# Create an empty list to store the ggplot objects
plots_list <- list()

# Loop from 1 to 9
suppressWarnings({
    for (i in 1:9) {
      # Create ggplot for each iteration
        CHR <- paste0("ch", i)
        CHR1 <- paste0("ch", i)
        plot <- dotplot(df1, order_by='provided',
                ordering= list(c(CHR), c(CHR1)),
                alignment_colour="blue",
                label_seqs = FALSE) +
        scale_x_continuous(breaks = c(0, 10000000, 20000000, 30000000, 40000000, 45000000), labels = c("0", "10", "20", "30", "40", "45"))+
        scale_y_continuous(breaks = c(0, 10000000, 20000000, 30000000, 40000000, 45000000), labels = c("0", "10", "20", "30", "40", "45"))+
        labs(x = CHR) +
        labs(y = "")

      # Name the ggplot object
      plot_name <- paste0("P", i)

      # Store the ggplot object in the list
      plots_list[[plot_name]] <- plot
    }

    # Arrange plots in a 3x3 grid
    hap1_dotplot <- grid.arrange(grobs = plots_list, nrow = 3, ncol = 3)
    hap1_dotplot
})

ggsave("hap1_genome_dotplot.pdf", hap1_dotplot, width = 6, height = 6)
# Out:
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Scale for y is already present.
# ...

# %%
# Create a dotplot visualization from the PAF data
suppressWarnings({
    options(repr.plot.width = 16, repr.plot.height = 8)
    
    plot_ch2 <- dotplot(df1, order_by='provided',
        ordering= list(c("ch2"),
        c("ch2")),
        alignment_colour="blue",
        label_seqs = TRUE) +
        scale_x_continuous(breaks = c(0, 10000000, 20000000, 30000000, 40000000, 45000000), labels = c("0", "10", "20", "30", "40", "45"))+
        scale_y_continuous(breaks = c(0, 10000000, 20000000, 30000000, 40000000, 45000000), labels = c("0", "10", "20", "30", "40", "45"))+
        labs(x = "ch2") +
        ggtitle("Hap1 chromosome 2") +  # Adding title
        theme(plot.title = element_text(size = 20, face = "bold"),
                axis.text = element_text(size = 14),
                axis.title = element_text(size = 16))  # Customize title font size and weight
        
    plot_ch6 <- dotplot(df1, order_by='provided',
        ordering= list(c("ch6"),
        c("ch6")),
        alignment_colour="blue",
        label_seqs = TRUE) +
        scale_x_continuous(breaks = c(0, 10000000, 20000000, 30000000, 40000000, 45000000), labels = c("0", "10", "20", "30", "40", "45"))+
        scale_y_continuous(breaks = c(0, 10000000, 20000000, 30000000, 40000000, 45000000), labels = c("0", "10", "20", "30", "40", "45"))+
        labs(x = "ch6") +
        ggtitle("Hap1 chromosome 6") + # Adding title
        theme(plot.title = element_text(size = 20, face = "bold"),
                axis.text = element_text(size = 14),
                axis.title = element_text(size = 16))  # Customize title font size and weight
        
    hap1_ch2_ch6_dotplot <- grid.arrange(grobs = list(plot_ch2,plot_ch6), nrow = 1, ncol = 2)
    hap1_ch2_ch6_dotplot
        })
ggsave("hap1_ch2_ch6_dotplot.pdf", hap1_ch2_ch6_dotplot, width = 10, height = 10)
# Out:
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# TableGrob (1 x 2) "arrange": 2 grobs
#   z     cells    name           grob
# 1 1 (1-1,1-1) arrange gtable[layout]
# 2 2 (1-1,2-2) arrange gtable[layout]
# plot without title

# %% [markdown]
# ### Hap2_genome.aln

# %%
# load paf data

df2 <- read_paf("output_sed_hap2/hap2_aln.paf")

# Create an empty list to store the ggplot objects
plots_list <- list()

# Loop from 1 to 9
suppressWarnings({
    options(repr.plot.width = 10, repr.plot.height = 10)
    for (i in 1:9) {
      # Create ggplot for each iteration
        CHR <- paste0("ch", i)
        CHR1 <- paste0("ch", i)
        plot <- dotplot(df2, order_by='provided',
                ordering= list(c(CHR), c(CHR1)),
                alignment_colour="red",
                label_seqs = FALSE) +
        scale_x_continuous(breaks = c(0, 10000000, 20000000, 30000000, 40000000, 45000000), labels = c("0", "10", "20", "30", "40", "45"))+
        scale_y_continuous(breaks = c(0, 10000000, 20000000, 30000000, 40000000, 45000000), labels = c("0", "10", "20", "30", "40", "45"))+
        labs(x = CHR) +
        labs(y = "")

      # Name the ggplot object
      plot_name <- paste0("P", i)

      # Store the ggplot object in the list
      plots_list[[plot_name]] <- plot
    }

    # Arrange plots in a 3x3 grid
    hap2_dotplot <- grid.arrange(grobs = plots_list, nrow = 3, ncol = 3)
    hap2_dotplot
})

ggsave("hap2_genome_dotplot.pdf", hap2_dotplot, width = 6, height = 6)
# Out:
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Scale for y is already present.
# ...

# %%
# Create a dotplot visualization from the PAF data
suppressWarnings({
    options(repr.plot.width = 16, repr.plot.height = 8)
    
    plot_ch2 <- dotplot(df2, order_by='provided',
        ordering= list(c("ch2"),
        c("ch2")),
        alignment_colour="red",
        label_seqs = TRUE) +
        scale_x_continuous(breaks = c(0, 10000000, 20000000, 30000000, 40000000, 45000000), labels = c("0", "10", "20", "30", "40", "45"))+
        scale_y_continuous(breaks = c(0, 10000000, 20000000, 30000000, 40000000, 45000000), labels = c("0", "10", "20", "30", "40", "45"))+
        labs(x = "ch2") +
        ggtitle("Hap2 chromosome 2") +  # Adding title
        theme(plot.title = element_text(size = 20, face = "bold"),
                axis.text = element_text(size = 14),
                axis.title = element_text(size = 16))  # Customize title font size and weight
        
    plot_ch6 <- dotplot(df2, order_by='provided',
        ordering= list(c("ch6"),
        c("ch6")),
        alignment_colour="red",
        label_seqs = TRUE) +
        scale_x_continuous(breaks = c(0, 10000000, 20000000, 30000000, 40000000, 45000000), labels = c("0", "10", "20", "30", "40", "45"))+
        scale_y_continuous(breaks = c(0, 10000000, 20000000, 30000000, 40000000, 45000000), labels = c("0", "10", "20", "30", "40", "45"))+
        labs(x = "ch6") +
        ggtitle("Hap2 chromosome 6") + # Adding title
        theme(plot.title = element_text(size = 20, face = "bold"),
                axis.text = element_text(size = 14),
                axis.title = element_text(size = 16))  # Customize title font size and weight
        
    hap2_ch2_ch6_dotplot <- grid.arrange(grobs = list(plot_ch2,plot_ch6), nrow = 1, ncol = 2)
    hap2_ch2_ch6_dotplot
        })
ggsave("hap2_ch2_ch6_dotplot.pdf", hap2_ch2_ch6_dotplot, width = 10, height = 10)
# Out:
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# TableGrob (1 x 2) "arrange": 2 grobs
#   z     cells    name           grob
# 1 1 (1-1,1-1) arrange gtable[layout]
# 2 2 (1-1,2-2) arrange gtable[layout]
# plot without title

# %%
mean(ali$alen)
# Out:
# [1] 46553.33

# %%
unique(df1$tname)
# Out:
#   [1] "Scaffold1"   "Scaffold127" "Scaffold18"  "Scaffold199" "Scaffold166"
#   [6] "Scaffold188" "Scaffold186" "Scaffold189" "Scaffold190" "Scaffold193"
#  [11] "Scaffold194" "Scaffold197" "Scaffold220" "Scaffold20"  "Scaffold223"
#  [16] "Scaffold108" "Scaffold200" "Scaffold120" "Scaffold93"  "Scaffold44"
#  [21] "Scaffold3"   "Scaffold77"  "Scaffold155" "Scaffold21"  "Scaffold25"
#  [26] "Scaffold227" "Scaffold203" "Scaffold202" "Scaffold205" "Scaffold63"
#  [31] "Scaffold210" "Scaffold211" "Scaffold85"  "Scaffold150" "Scaffold129"
#  [36] "Scaffold47"  "Scaffold119" "Scaffold165" "Scaffold67"  "Scaffold174"
#  [41] "Scaffold138" "Scaffold147" "Scaffold69"  "chr1"        "Scaffold216"
#  [46] "Scaffold124" "Scaffold22"  "Scaffold34"  "Scaffold42"  "Scaffold58"
#  [51] "Scaffold106" "Scaffold121" "chr9"        "Scaffold75"  "Scaffold54"
#  [56] "Scaffold152" "Scaffold28"  "Scaffold81"  "Scaffold70"  "Scaffold154"
# ...

# %%
unique(long_ali$tname)
# Out:
#   [1] "Scaffold1"   "Scaffold127" "Scaffold18"  "Scaffold199" "Scaffold166"
#   [6] "Scaffold188" "Scaffold186" "Scaffold189" "Scaffold190" "Scaffold193"
#  [11] "Scaffold194" "Scaffold197" "Scaffold220" "Scaffold20"  "Scaffold223"
#  [16] "Scaffold200" "Scaffold203" "Scaffold202" "Scaffold205" "Scaffold63"
#  [21] "Scaffold210" "Scaffold211" "Scaffold85"  "Scaffold150" "Scaffold129"
#  [26] "Scaffold47"  "Scaffold119" "Scaffold165" "Scaffold67"  "Scaffold174"
#  [31] "Scaffold138" "Scaffold147" "Scaffold69"  "Scaffold216" "Scaffold124"
#  [36] "Scaffold22"  "Scaffold34"  "Scaffold42"  "Scaffold58"  "Scaffold106"
#  [41] "Scaffold121" "chr9"        "Scaffold75"  "Scaffold54"  "Scaffold152"
#  [46] "Scaffold28"  "Scaffold81"  "Scaffold70"  "Scaffold154" "Scaffold51"
#  [51] "Scaffold57"  "chr1"        "chr2"        "chr3"        "chr8"
#  [56] "chr7"        "chr5"        "chr6"        "chr4"        "Scaffold156"
# ...

# %%
filtered_df <- subset(df1, qname == "chr3" & tname == "chr3")

# %%
head(filtered_df)
# Out:
#    qname qlen     qstart   qend     strand tname tlen     tstart   tend
# 81 chr3  32424507 19313763 19407570 +      chr3  34304306 21454068 21539537
# 82 chr3  32424507 17683677 17763818 +      chr3  34304306 19803390 19889796
# 83 chr3  32424507 17800568 17865910 +      chr3  34304306 19973561 20034502
# 84 chr3  32424507   684599   743966 +      chr3  34304306   813427   874897
# 85 chr3  32424507  9529054  9588554 +      chr3  34304306 10084631 10144931
# 86 chr3  32424507 13017615 13078530 +      chr3  34304306 13869646 13941818
#    nmatch ⋯ AS    nn tp cm   s1    s2    de     rl
# 81 67678  ⋯  1349 0  P  3491 35180 21021 0.0324 1312852
# 82 60099  ⋯ -5432 0  P  3173 31976 21021 0.0317 1312852
# 83 57340  ⋯ 28258 0  P  3515 35422 21021 0.0263 1312852
# 84 57395  ⋯ 32583 0  P  3751 35048 25520 0.0238 1312852
# 85 56395  ⋯ 31755 0  P  3477 32492 25520 0.0252 1312852
# 86 56447  ⋯ 18173 0  P  3388 31686 25520 0.0280 1312852
#    cg
# 81 ...
# 82 ...
# 83 ...
# 84 ...
# 85 ...
# ...

# %%
mean(filtered_df$alen)
# Out:
# [1] 9006.043

# %%
# Create a synteny plot for a specific chromosome pair
# (Adjust 'q_chrom' and 't_chrom' to match the desired chromosomes)
options(repr.plot.width = 10, repr.plot.height = 6)
filtered_df <- subset(df1, qname == "chr3" & tname == "chr3" & alen > 9000)

plot2 <- plot_synteny(filtered_df, q_chrom = "chr3", t_chrom = "chr3", centre = TRUE)
plot2
#ggsave("synteny_chr2_plot.pdf", plot2, width = 18, height = 6)
# Out:
# plot without title

# %%
head(df1)
# Out:
#   qname       qlen   qstart qend   strand tname       tlen   tstart tend
# 1 Scaffold1    57716      0  57716 +      Scaffold1    79673     0   57683
# 2 Scaffold127  30268      0  30268 +      Scaffold127  30268     0   30268
# 3 Scaffold13  154852  20215 124619 +      Scaffold18  110041     0  110041
# 4 Scaffold13  154852  49835 111108 +      Scaffold199 285769     0   61928
# 5 Scaffold13  154852 121291 136758 +      Scaffold199 285769 67560   83745
# 6 Scaffold13  154852 146809 154852 +      Scaffold199 285769 93755  101802
#   nmatch ⋯ AS    nn tp cm  s1   s2   de     rl
# 1  57667 ⋯ 57124 0  P  653 7175 3572 0.0002  51610
# 2  30268 ⋯ 30268 0  P  223 2995  806 0.0000  28783
# 3 103343 ⋯ 92656 0  P  470 4890 6043 0.0022 140856
# 4  61192 ⋯ 59657 0  S  604 6043   NA 0.0007 140856
# 5  15414 ⋯ 12639 0  P   26  260 7264 0.0043 140856
# 6   8034 ⋯  7569 0  P  291 2911 7264 0.0019 140856
#   cg
# 1 38482M11D36M1I129M1I112M1I43M1I170M1D14M38I100M1I192M1I13900M1I4493M
# 2 30268M
# ...

# %%
# Create a coverage plot, filling based on the query sequences
options(repr.plot.width = 12, repr.plot.height = 6)
qname_list <- list("ch1","ch2","ch3","ch4","ch5","ch6","ch7","ch8","ch9")
filtered_df1 <- subset(df1, qname %in% qname_list)
plot_coverage <- plot_coverage(filtered_df1, fill = "qname")
plot_coverage
ggsave("hap1_coverage.pdf", plot_coverage, width = 12, height = 6)
# Out:
# plot without title

# %%
# Create a coverage plot, filling based on the query sequences
options(repr.plot.width = 12, repr.plot.height = 6)
qname_list <- list("ch1","ch2","ch3","ch4","ch5","ch6","ch7","ch8","ch9")
filtered_df2 <- subset(df2, qname %in% qname_list)
plot_coverage <- plot_coverage(filtered_df2, fill = "qname")
plot_coverage
ggsave("hap2_coverage.pdf", plot_coverage, width = 12, height = 6)
# Out:
# plot without title

# %% [markdown]
# ## Hap1.scaffold aligned to Hap2.scaffold

# %%
# Set the plot size
options(repr.plot.width=10, repr.plot.height=10)  # Adjust width and height as needed

hap1hap2 <- read_paf("hap1_hap2_sed_aln.paf")
filtered1_hap1hap2 <- subset(hap1hap2, qname %in% qname_list)
filtered2_hap1hap2 <- subset(filtered1_hap1hap2, tname %in% qname_list)

hap1hap2_dotplot <- dotplot(filtered2_hap1hap2,
                        label_seqs = TRUE,
                        order_by='provided',
                        ordering= list(c("ch1","ch2","ch3","ch4","ch5","ch6","ch7","ch8","ch9"),
                            c("ch1","ch2","ch3","ch4","ch5","ch6","ch7","ch8","ch9")),
                        alignment_colour="blue") +
                        ggtitle("hap1hap2 dotplot") +  # Adding title
                        theme(plot.title = element_text(size = 20, face = "bold"),
                        axis.text = element_text(size = 14),
                        axis.title = element_text(size = 16))  # Customize title font size and weight
hap1hap2_dotplot
ggsave("hap1hap2_dotplot.pdf", hap1hap2_dotplot, width = 10, height = 10)
# Out:
# plot without title

# %%
# load paf data

# Create an empty list to store the ggplot objects
plots_list <- list()

# Loop from 1 to 9
suppressWarnings({
    options(repr.plot.width = 8, repr.plot.height = 8)
    for (i in 1:9) {
      # Create ggplot for each iteration
        CHR <- paste0("ch", i)
        CHR1 <- paste0("ch", i)
        plot <- dotplot(hap1hap2, order_by='provided',
                ordering= list(c(CHR), c(CHR1)),
                alignment_colour="purple",
                label_seqs = FALSE) +
        scale_x_continuous(breaks = c(0, 10000000, 20000000, 30000000, 40000000, 45000000), labels = c("0", "10", "20", "30", "40", "45"))+
        scale_y_continuous(breaks = c(0, 10000000, 20000000, 30000000, 40000000, 45000000), labels = c("0", "10", "20", "30", "40", "45"))+
        labs(x = CHR) +
        labs(y = "")

      # Name the ggplot object
      plot_name <- paste0("P", i)

      # Store the ggplot object in the list
      plots_list[[plot_name]] <- plot
    }

    # Arrange plots in a 3x3 grid
    hap1hap2_dotplot <- grid.arrange(grobs = plots_list, nrow = 3, ncol = 3)
    hap1hap2_dotplot
})

ggsave("hap1hap2_dotplot.pdf", hap1hap2_dotplot, width = 8, height = 8)
# Out:
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Scale for y is already present.
# ...

# %%
# Create a dotplot visualization from the PAF data
suppressWarnings({
    options(repr.plot.width = 8, repr.plot.height = 8)
    
    plot_ch2 <- dotplot(hap1hap2, order_by='provided',
        ordering= list(c("ch2"),
        c("ch2")),
        alignment_colour="purple",
        label_seqs = TRUE) +
        scale_x_continuous(breaks = c(0, 10000000, 20000000, 30000000, 40000000, 45000000), labels = c("0", "10", "20", "30", "40", "45"))+
        scale_y_continuous(breaks = c(0, 10000000, 20000000, 30000000, 40000000, 45000000), labels = c("0", "10", "20", "30", "40", "45"))+
        labs(x = "ch2") +
        ggtitle("hap1hap2 chrosome 2") +  # Adding title
        theme(plot.title = element_text(size = 20, face = "bold"),
                axis.text = element_text(size = 14),
                axis.title = element_text(size = 16))  # Customize title font size and weight
                
    ggsave("hap1hap2_ch2.pdf", plot_ch2, width = 8, height = 8)
        })

plot_ch2
# Out:
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# plot without title

# %%
# Create a coverage plot, filling based on the query sequences
options(repr.plot.width = 18, repr.plot.height = 10)
qname_list <- list("ch1","ch2","ch3","ch4","ch5","ch6","ch7","ch8","ch9")
filtered_hap1hap2 <- subset(hap1hap2, qname %in% qname_list & tname %in% qname_list)
coverage_hap1hap2 <- plot_coverage(filtered_hap1hap2, fill = "qname") +
                        ggtitle("hap1hap2 chrosome 2") +  # Adding title
                theme(plot.title = element_text(size = 20, face = "bold"),
                axis.text = element_text(size = 14),
                axis.title = element_text(size = 16),
                legend.text = element_text(size = 14))  # Customize title font size and weight
coverage_hap1hap2
ggsave("coverage_hap1hap2.pdf", coverage_hap1hap2, width = 18, height = 10)
# Out:
# plot without title

# %%
# Create a synteny plot for a specific chromosome pair
# (Adjust 'q_chrom' and 't_chrom' to match the desired chromosomes)
options(repr.plot.width = 10, repr.plot.height = 6)
#hap1hap2_chr3 <- subset(hap1hap2, qname == "chr3" & tname == "chr3")

plot_hap1hap2_ch2 <- plot_synteny(hap1hap2, q_chrom = "ch2", t_chrom = "ch3", centre = TRUE)
plot_hap1hap2_ch2
#ggsave("synteny_chr2_plot.pdf", plot2, width = 18, height = 6)
# Out:
# plot without title

# %%
# Create a synteny plot for a specific chromosome pair
# (Adjust 'q_chrom' and 't_chrom' to match the desired chromosomes)
options(repr.plot.width = 10, repr.plot.height = 6)
#hap1hap2_chr3 <- subset(hap1hap2, qname == "chr3" & tname == "chr3")

plot_hap1hap2_ch2 <- plot_synteny(hap1hap2, q_chrom = "ch3", t_chrom = "ch3", centre = TRUE)
plot_hap1hap2_ch2
ggsave("hap1hap2_synteny_ch2_plot.pdf", plot_hap1hap2_ch2, width = 10, height = 6)
# Out:
# plot without title
